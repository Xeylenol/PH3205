# %% [markdown]
# # General information

# %% [markdown]
# ## Syllabus
# - Numerical precision and general programming
# - Root finding
# - ODE: Euler, midpoint, RK4
# - ODE: Verlet, Velocity Verlet, Leap Frog, RK2
# - Adaptive timestepping
# - Boundary value problems: Shooting method. Schroedinger equation.
# - Boundary value problems: Heat equation. Crank-Nicolson.
# - Time-dependent Schroedinger Equation
# - Random walk
# - Importance sampling (Metropolis)

# %% [markdown]
# ## Grading Scheme
# - Worksheets 40
# - Class test(s) 30
# - Endsem 30

# %% [markdown]
# ## Class details
# - Theory: Tuesdays 1:30 pm, G05 LHC
# - Lab: Tuesdays 3:10 pm, Computer Center 1 (CC1) AAC
# - Lab: Tursdays 3:10 pm, Computer Center 1 (CC1) AAC

# %% [markdown]
# # General tips
#
# - Type stability
# - Use vectorization
# - Use list comprehension

# %% [markdown]
# ## Double precision

# %%
a = 1.0
count = 0
while a>0.0:
    print(count, a)
    a /= 2
    count += 1

# %%
a = 1.0
count = 0
while a + 1.0 > 1.0:
    print(count, a)
    a = a/2
    count += 1

# %%
1/2**52
